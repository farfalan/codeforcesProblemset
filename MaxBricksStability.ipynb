# %% [markdown]
# <a href="https://colab.research.google.com/github/farfalan/codeforcesProblemset/blob/main/MaxBricksStability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://codeforces.com/problemset/problem/1918/A
n = 10000
m = 10000

counter = 0

while m >= 2:
    m -= 2
    counter += 1
print(counter * n )
# Out:
# 50000000
